# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
#
#                     *          ---------------------------Expression
#
#                     'hello'   ----------------------------Value
#
#                     -87.8      ---------------------------value
#
#                     -          ---------------------------expression
#
#                     /          ---------------------------expression
#
#                     +	       ---------------------------expression
#
#                     6          ---------------------------Values

# %% [markdown]
# 2. What is the difference between string and variable?
#
#
#  String is simply a series of character. Anything inside quotes(single or double) considered a string in python.
#
#  A variable is a container which contain some value. Name of the variable represent what information the variable contains

# %% [markdown]
# 3. Describe three different data types.
#
#
#    Integers- Represented by int class. Without fraction or decimal it can be positive or nagative whole number.
#
#    Float- Reptresented by float class. It's identified by a decimal point.
#
#    Complex Number- Represented by a complex class. Identifies as a real part +    complex part.

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?
#
#   An expression is a combination of values, variables and operators. All expression do represent the value.

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
#   Expression evaluates value and statement represent an action like print statement, assignment         statement.

# %%
#6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1
# Out:
# 23

# %%
#7. What should the values of the following two terms be?
'spam' + 'spamspam'
'spam' * 3
# Out:
# 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?
#
#   Cause you can't start variable name with a number.
