# %%
1. Write a python program to print "Hello Python?".

# %%
greeting = "Hello Python?"
print(greeting)
# Out:
# Hello Python?

# %%
2. Write a Python program to do arithmetical operations addition and division.

# %%
a = 100
b = 10

print(a+b)
print(a/b)
# Out:
# 110
# 10.0

# %%
3. Write a python program to find the area of triagle.

# %%
n = 9
i = 0

while i < n:
    print(' '*(n-i-1) + '* '*(i+1))
    i +=1
# Out:
#         *
#        * *
#       * * *
#      * * * *
#     * * * * *
#    * * * * * *
#   * * * * * * *
#  * * * * * * * *
# * * * * * * * * *

# %%
4. Write a python program to swap two variable.

# %%
x = 5
y = 10

x, y = y, x
print("x =", x)
print("y =", y)
# Out:
# x = 10
# y = 5

# %%
5. Write a Python program to generate a random number

# %%
import random

n = random.random()
print(n)
# Out:
# 0.0331941589618745
